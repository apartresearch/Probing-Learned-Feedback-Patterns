# %%
import wandb
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
from collections import OrderedDict
from datasets import Dataset
from transformers import AutoModel, AutoTokenizer
import requests
import re

# %%
! rm -rf Interpreting-Reward-Models || true
! git clone https://github.com/apartresearch/Interpreting-Reward-Models.git
! cd Interpreting-Reward-Models && pip install .
# Out:
# Cloning into 'Interpreting-Reward-Models'...
# remote: Enumerating objects: 1957, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 1957 (delta 77), reused 75 (delta 48), pack-reused 1770
# Receiving objects: 100% (1957/1957), 477.31 KiB | 13.26 MiB/s, done.
# Resolving deltas: 100% (1354/1354), done.
# WARNING: Ignoring invalid distribution -orch (/data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages)
# Processing /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/Interpreting-Reward-Models
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate==0.30.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (0.30.0)
# Requirement already satisfied: bitsandbytes==0.41.* in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (0.41.3.post2)
# Requirement already satisfied: circuitsvis==1.41.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (1.41.0)
# Requirement already satisfied: datasets==2.17.* in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (2.17.1)
# Requirement already satisfied: diskcache==5.6.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (5.6.3)
# Requirement already satisfied: einops==0.6.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (0.6.1)
# Requirement already satisfied: guidance==0.1.10 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (0.1.10)
# Requirement already satisfied: huggingface-hub in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (0.23.0)
# Requirement already satisfied: jupyter==1.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (1.0.0)
# Requirement already satisfied: nltk==3.8.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (3.8.1)
# Requirement already satisfied: protobuf==4.25.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (4.25.1)
# Requirement already satisfied: pylint==3.0.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (3.0.1)
# Requirement already satisfied: pynvml==11.5.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (11.5.0)
# Requirement already satisfied: scikit-learn==1.4.1.post1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (1.4.1.post1)
# Requirement already satisfied: scipy==1.10.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (1.10.1)
# Requirement already satisfied: seaborn==0.13.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (0.13.2)
# Requirement already satisfied: sentencepiece==0.1.99 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (0.1.99)
# Requirement already satisfied: spacy==3.7.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (3.7.2)
# Requirement already satisfied: torch==2.0.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (2.0.1)
# Requirement already satisfied: transformers==4.38.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (4.38.2)
# Requirement already satisfied: transformer-lens==1.17.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (1.17.0)
# Requirement already satisfied: trl==0.7.7 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (0.7.7)
# Requirement already satisfied: wandb==0.16.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (0.16.1)
# Requirement already satisfied: wheel in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from reward_analyzer==0.9.0) (0.43.0)
# Requirement already satisfied: numpy>=1.17 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from accelerate==0.30.0->reward_analyzer==0.9.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from accelerate==0.30.0->reward_analyzer==0.9.0) (24.0)
# Requirement already satisfied: psutil in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from accelerate==0.30.0->reward_analyzer==0.9.0) (5.9.8)
# Requirement already satisfied: pyyaml in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from accelerate==0.30.0->reward_analyzer==0.9.0) (6.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from accelerate==0.30.0->reward_analyzer==0.9.0) (0.4.3)
# Requirement already satisfied: importlib-metadata<6.0.0,>=5.1.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from circuitsvis==1.41.0->reward_analyzer==0.9.0) (5.2.0)
# Requirement already satisfied: filelock in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from datasets==2.17.*->reward_analyzer==0.9.0) (3.13.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from datasets==2.17.*->reward_analyzer==0.9.0) (16.0.0)
# Requirement already satisfied: pyarrow-hotfix in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from datasets==2.17.*->reward_analyzer==0.9.0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from datasets==2.17.*->reward_analyzer==0.9.0) (0.3.8)
# Requirement already satisfied: pandas in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from datasets==2.17.*->reward_analyzer==0.9.0) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from datasets==2.17.*->reward_analyzer==0.9.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from datasets==2.17.*->reward_analyzer==0.9.0) (4.66.4)
# Requirement already satisfied: xxhash in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from datasets==2.17.*->reward_analyzer==0.9.0) (3.4.1)
# Requirement already satisfied: multiprocess in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from datasets==2.17.*->reward_analyzer==0.9.0) (0.70.16)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.17.*->reward_analyzer==0.9.0) (2023.10.0)
# Requirement already satisfied: aiohttp in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from datasets==2.17.*->reward_analyzer==0.9.0) (3.9.5)
# Requirement already satisfied: gptcache in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from guidance==0.1.10->reward_analyzer==0.9.0) (0.1.43)
# Requirement already satisfied: openai>=1.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from guidance==0.1.10->reward_analyzer==0.9.0) (1.28.1)
# Requirement already satisfied: platformdirs in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from guidance==0.1.10->reward_analyzer==0.9.0) (4.2.1)
# Requirement already satisfied: tiktoken>=0.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from guidance==0.1.10->reward_analyzer==0.9.0) (0.6.0)
# Requirement already satisfied: msal in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from guidance==0.1.10->reward_analyzer==0.9.0) (1.28.0)
# Requirement already satisfied: ordered-set in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from guidance==0.1.10->reward_analyzer==0.9.0) (4.1.0)
# Requirement already satisfied: pyformlang in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from guidance==0.1.10->reward_analyzer==0.9.0) (1.0.10)
# Requirement already satisfied: notebook in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter==1.0.0->reward_analyzer==0.9.0) (7.1.3)
# Requirement already satisfied: qtconsole in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter==1.0.0->reward_analyzer==0.9.0) (5.5.2)
# Requirement already satisfied: jupyter-console in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter==1.0.0->reward_analyzer==0.9.0) (6.6.3)
# Requirement already satisfied: nbconvert in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter==1.0.0->reward_analyzer==0.9.0) (7.16.4)
# Requirement already satisfied: ipykernel in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter==1.0.0->reward_analyzer==0.9.0) (6.29.4)
# Requirement already satisfied: ipywidgets in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter==1.0.0->reward_analyzer==0.9.0) (8.1.2)
# Requirement already satisfied: click in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nltk==3.8.1->reward_analyzer==0.9.0) (8.1.7)
# Requirement already satisfied: joblib in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nltk==3.8.1->reward_analyzer==0.9.0) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nltk==3.8.1->reward_analyzer==0.9.0) (2024.5.10)
# Requirement already satisfied: astroid<=3.1.0-dev0,>=3.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pylint==3.0.1->reward_analyzer==0.9.0) (3.0.3)
# Requirement already satisfied: isort<6,>=4.2.5 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pylint==3.0.1->reward_analyzer==0.9.0) (5.13.2)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pylint==3.0.1->reward_analyzer==0.9.0) (0.7.0)
# Requirement already satisfied: tomlkit>=0.10.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pylint==3.0.1->reward_analyzer==0.9.0) (0.12.5)
# Requirement already satisfied: tomli>=1.1.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pylint==3.0.1->reward_analyzer==0.9.0) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from scikit-learn==1.4.1.post1->reward_analyzer==0.9.0) (3.5.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from seaborn==0.13.2->reward_analyzer==0.9.0) (3.8.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (2.7.1)
# Requirement already satisfied: jinja2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (3.1.3)
# Requirement already satisfied: setuptools in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (65.5.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from spacy==3.7.2->reward_analyzer==0.9.0) (3.4.0)
# Requirement already satisfied: typing-extensions in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (4.11.0)
# Requirement already satisfied: sympy in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (1.12)
# Requirement already satisfied: networkx in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from torch==2.0.1->reward_analyzer==0.9.0) (2.0.0)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from transformer-lens==1.17.0->reward_analyzer==0.9.0) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from transformer-lens==1.17.0->reward_analyzer==0.9.0) (0.0.3)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from transformer-lens==1.17.0->reward_analyzer==0.9.0) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from transformer-lens==1.17.0->reward_analyzer==0.9.0) (0.2.28)
# Requirement already satisfied: rich>=12.6.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from transformer-lens==1.17.0->reward_analyzer==0.9.0) (13.7.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from transformers==4.38.2->reward_analyzer==0.9.0) (0.15.2)
# Requirement already satisfied: tyro>=0.5.11 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from trl==0.7.7->reward_analyzer==0.9.0) (0.8.4)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from wandb==0.16.1->reward_analyzer==0.9.0) (3.1.43)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from wandb==0.16.1->reward_analyzer==0.9.0) (2.1.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from wandb==0.16.1->reward_analyzer==0.9.0) (0.4.0)
# Requirement already satisfied: setproctitle in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from wandb==0.16.1->reward_analyzer==0.9.0) (1.3.3)
# Requirement already satisfied: appdirs>=1.4.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from wandb==0.16.1->reward_analyzer==0.9.0) (1.4.4)
# Requirement already satisfied: cmake in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from triton==2.0.0->torch==2.0.1->reward_analyzer==0.9.0) (3.29.3)
# Requirement already satisfied: lit in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from triton==2.0.0->torch==2.0.1->reward_analyzer==0.9.0) (18.1.4)
# Requirement already satisfied: six>=1.4.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb==0.16.1->reward_analyzer==0.9.0) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from aiohttp->datasets==2.17.*->reward_analyzer==0.9.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from aiohttp->datasets==2.17.*->reward_analyzer==0.9.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from aiohttp->datasets==2.17.*->reward_analyzer==0.9.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from aiohttp->datasets==2.17.*->reward_analyzer==0.9.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from aiohttp->datasets==2.17.*->reward_analyzer==0.9.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from aiohttp->datasets==2.17.*->reward_analyzer==0.9.0) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.1->reward_analyzer==0.9.0) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from importlib-metadata<6.0.0,>=5.1.0->circuitsvis==1.41.0->reward_analyzer==0.9.0) (3.18.1)
# Requirement already satisfied: typeguard==2.13.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jaxtyping>=0.2.11->transformer-lens==1.17.0->reward_analyzer==0.9.0) (2.13.3)
# Requirement already satisfied: language-data>=1.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy==3.7.2->reward_analyzer==0.9.0) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->reward_analyzer==0.9.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->reward_analyzer==0.9.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->reward_analyzer==0.9.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->reward_analyzer==0.9.0) (1.4.5)
# Requirement already satisfied: pillow>=8 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->reward_analyzer==0.9.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->reward_analyzer==0.9.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->reward_analyzer==0.9.0) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from openai>=1.0->guidance==0.1.10->reward_analyzer==0.9.0) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from openai>=1.0->guidance==0.1.10->reward_analyzer==0.9.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from openai>=1.0->guidance==0.1.10->reward_analyzer==0.9.0) (0.27.0)
# Requirement already satisfied: sniffio in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from openai>=1.0->guidance==0.1.10->reward_analyzer==0.9.0) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pandas->datasets==2.17.*->reward_analyzer==0.9.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pandas->datasets==2.17.*->reward_analyzer==0.9.0) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.2->reward_analyzer==0.9.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.2->reward_analyzer==0.9.0) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from requests>=2.19.0->datasets==2.17.*->reward_analyzer==0.9.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from requests>=2.19.0->datasets==2.17.*->reward_analyzer==0.9.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from requests>=2.19.0->datasets==2.17.*->reward_analyzer==0.9.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from requests>=2.19.0->datasets==2.17.*->reward_analyzer==0.9.0) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from rich>=12.6.0->transformer-lens==1.17.0->reward_analyzer==0.9.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from rich>=12.6.0->transformer-lens==1.17.0->reward_analyzer==0.9.0) (2.18.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy==3.7.2->reward_analyzer==0.9.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy==3.7.2->reward_analyzer==0.9.0) (0.1.4)
# Requirement already satisfied: docstring-parser>=0.14.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.7.7->reward_analyzer==0.9.0) (0.16)
# Requirement already satisfied: shtab>=1.5.6 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.7.7->reward_analyzer==0.9.0) (1.7.1)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy==3.7.2->reward_analyzer==0.9.0) (0.16.0)
# Requirement already satisfied: cachetools in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from gptcache->guidance==0.1.10->reward_analyzer==0.9.0) (5.3.3)
# Requirement already satisfied: comm>=0.1.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (8.24.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (0.1.7)
# Requirement already satisfied: nest-asyncio in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->reward_analyzer==0.9.0) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->reward_analyzer==0.9.0) (3.0.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jinja2->spacy==3.7.2->reward_analyzer==0.9.0) (2.1.5)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->reward_analyzer==0.9.0) (3.0.43)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal->guidance==0.1.10->reward_analyzer==0.9.0) (2.8.0)
# Requirement already satisfied: cryptography<45,>=0.6 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from msal->guidance==0.1.10->reward_analyzer==0.9.0) (42.0.7)
# Requirement already satisfied: beautifulsoup4 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (6.1.0)
# Requirement already satisfied: defusedxml in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (1.5.1)
# Requirement already satisfied: tinycss2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (2.27.1)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (4.1.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (0.2.4)
# Requirement already satisfied: pydot in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pyformlang->guidance==0.1.10->reward_analyzer==0.9.0) (2.0.0)
# Requirement already satisfied: qtpy>=2.4.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from qtconsole->jupyter==1.0.0->reward_analyzer==0.9.0) (2.4.1)
# Requirement already satisfied: mpmath>=0.19 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from sympy->torch==2.0.1->reward_analyzer==0.9.0) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.0->guidance==0.1.10->reward_analyzer==0.9.0) (1.2.1)
# Requirement already satisfied: webencodings in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (0.5.1)
# Requirement already satisfied: cffi>=1.12 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from cryptography<45,>=0.6->msal->guidance==0.1.10->reward_analyzer==0.9.0) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.1->reward_analyzer==0.9.0) (5.0.1)
# Requirement already satisfied: httpcore==1.* in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.0->guidance==0.1.10->reward_analyzer==0.9.0) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->guidance==0.1.10->reward_analyzer==0.9.0) (0.14.0)
# Requirement already satisfied: decorator in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (0.19.1)
# Requirement already satisfied: stack-data in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (4.22.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.7.2->reward_analyzer==0.9.0) (1.1.1)
# Requirement already satisfied: mdurl~=0.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens==1.17.0->reward_analyzer==0.9.0) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (2.19.1)
# Requirement already satisfied: wcwidth in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->reward_analyzer==0.9.0) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->reward_analyzer==0.9.0) (2.5)
# Requirement already satisfied: argon2-cffi-bindings in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (21.2.0)
# Requirement already satisfied: pycparser in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from cffi>=1.12->cryptography<45,>=0.6->msal->guidance==0.1.10->reward_analyzer==0.9.0) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (2.4.1)
# Requirement already satisfied: pure-eval in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->reward_analyzer==0.9.0) (0.2.2)
# Requirement already satisfied: fqdn in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (1.5.1)
# Requirement already satisfied: isoduration in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (2.4)
# Requirement already satisfied: uri-template in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->reward_analyzer==0.9.0) (2.9.0.20240316)
# Building wheels for collected packages: reward_analyzer
#   Building wheel for reward_analyzer (pyproject.toml) ... done
#   Created wheel for reward_analyzer: filename=reward_analyzer-0.9.0-py3-none-any.whl size=35426 sha256=50b3647e3f08df8ad02b2db6d362bcd3d86ff472dc6facbf8ead7ef3ad9b6401
#   Stored in directory: /data/home/amir/.cache/pip/wheels/00/30/30/14f029d0e571a2cf2e6cf99dcd4fdc6e13a60775b24d496855
# Successfully built reward_analyzer
# WARNING: Ignoring invalid distribution -orch (/data/home/amir/work/venvs/rlhf/lib/python3.10/site-packages)
# Installing collected packages: reward_analyzer
#   Attempting uninstall: reward_analyzer
#     Found existing installation: reward_analyzer 0.9.0
#     Uninstalling reward_analyzer-0.9.0:
#       Successfully uninstalled reward_analyzer-0.9.0
# Successfully installed reward_analyzer-0.9.0

# %%
from reward_analyzer import SparseAutoencoder
from reward_analyzer.utils.model_storage_utils import load_autoencoders_for_artifact
from reward_analyzer.utils.transformer_utils import batch

# %%
model_name = 'gpt_neo_125m'
task_name = 'hh_rlhf'
version = 'v0'

if 'pythia' in model_name:
    layer_name_step = 'layers.{}.mlp'
elif 'neo' in model_name:
    layer_name_stem = 'h.{}.mlp'
elif 'gemma' in model_name:
    layer_name_stem = 'layers.{}.mlp'
else:
    raise Exception(f'Not familiar with model name family of {model_name}')

# %%
autoencoders_dict = load_autoencoders_for_artifact(f'nlp_and_interpretability/Autoencoder_training_hh_rlhf/autoencoders_{model_name}_{task_name}:{version}')
# Out:
# Loading artifact from nlp_and_interpretability/Autoencoder_training_hh_rlhf/autoencoders_gpt_neo_125m_hh_rlhf:v0
# wandb: Downloading large artifact autoencoders_gpt_neo_125m_hh_rlhf:v0, 67.67MB. 20 files...
# wandb:   20 of 20 files downloaded.
# Done. 0:0:0.2
# No explicit decoder created, only bias vector.
# Loaded 1 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/base_big/1
#
# No explicit decoder created, only bias vector.
# Loaded 2 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/base_big/2
#
# No explicit decoder created, only bias vector.
# Loaded 3 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/base_big/3
#
# No explicit decoder created, only bias vector.
# Loaded 4 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/base_big/4
#
# No explicit decoder created, only bias vector.
# Loaded 6 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/base_big/6
#
# No explicit decoder created, only bias vector.
# Loaded 1 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/base_small/1
#
# No explicit decoder created, only bias vector.
# Loaded 2 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/base_small/2
#
# No explicit decoder created, only bias vector.
# Loaded 3 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/base_small/3
#
# No explicit decoder created, only bias vector.
# Loaded 4 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/base_small/4
#
# No explicit decoder created, only bias vector.
# Loaded 6 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/base_small/6
#
# No explicit decoder created, only bias vector.
# Loaded 1 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/rlhf_big/1
#
# No explicit decoder created, only bias vector.
# Loaded 2 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/rlhf_big/2
#
# No explicit decoder created, only bias vector.
# Loaded 3 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/rlhf_big/3
#
# No explicit decoder created, only bias vector.
# Loaded 4 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/rlhf_big/4
#
# No explicit decoder created, only bias vector.
# Loaded 6 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/rlhf_big/6
#
# No explicit decoder created, only bias vector.
# Loaded 1 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/rlhf_small/1
#
# No explicit decoder created, only bias vector.
# Loaded 2 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/rlhf_small/2
#
# No explicit decoder created, only bias vector.
# Loaded 3 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/rlhf_small/3
#
# No explicit decoder created, only bias vector.
# Loaded 4 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/rlhf_small/4
#
# No explicit decoder created, only bias vector.
# Loaded 6 from /data/home/amir/work/codes/Interpreting-Reward-Models/Notebooks/artifacts/autoencoders_gpt_neo_125m_hh_rlhf:v0/saves/rlhf_small/6

# %%
rlhf_small = autoencoders_dict['rlhf_small']

# %%
def extract_and_process_activations(texts, model, tokenizer, layer_name_stem, autoencoders_dict):
    inputs = tokenizer(text, return_tensors="pt")
    token_ids = inputs["input_ids"].squeeze().tolist()
    activations = {}

    target_layer_names = [layer_name_stem.format(key) for key in autoencoders_dict.keys()]

    def get_activation(name):
        def hook(model, input, output):
            activations[name] = output.detach()
        return hook

    hooks = [
        module.register_forward_hook(get_activation(name))
        for name, module in model.named_modules()
        if name in target_layer_names
    ]

    with torch.no_grad():
        model(**inputs)

    for hook in hooks:
        hook.remove()

    specified_activations = [(name, activations[name]) for name in target_layer_names]
    concatenated_activations = [[] for _ in token_ids]

    for act, autoencoder_idx in zip(specified_activations, autoencoder_indices):
        name, act = act
        act = act.squeeze(0)
        autoencoder = autoencoders[autoencoder_idx]
        features, _ = autoencoder(act)
        for i in range(len(token_ids)):
            concatenated_activations[i].append(features[i].tolist())

    final_activations = {
        token_id: [item for sublist in concatenated_activations[i] for item in sublist]
        for i, token_id in enumerate(token_ids)
    }

    return final_activations

# %%
def save_training_dataset_to_wandb(training_dataset: Dataset, model_name, dataset_name="logistic_probe_data.hf"):
    out_filename = training_dataset.save_to_disk(dataset_name)
    
    my_artifact = wandb.Artifact(f"logistic_probe_training_dataset_{model_name}", type="data")
    
    # Add the list to the artifact
    my_artifact.add_file(local_path=out_filename, name="logistic_probe_training_dataset")

    metadata_dict = {
        "description": "Training dataset, with activations and rewards",
        "source": "Generated by my script",
        "num_examples": len(training_dataset),
        "split": "full"
    }

    my_artifact.metadata.update(metadata_dict)

    # Log the artifact to the run
    wandb.log_artifact(my_artifact)

save_training_dataset_to_wandb(full_training_dataset, model_name=model_name)
